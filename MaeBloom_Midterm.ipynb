# %% [markdown]
# <a href="https://colab.research.google.com/github/maefl0wer/Statistics2022/blob/main/MaeBloom_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STA 2023 Midterm Project
#
# Directions:
#
# *   Use any and all resources available to you
# *   Comment and explain the code
# *   Answer the questions to the best of your abilities
# *   There are no points for pain: ask for help
#
# Save this notebook to your GitHub and submit the link.

# %%
import numpy as np
import matplotlib.pyplot as plt
#getting all of the math imports we need for math and plotting graphs

# %% [markdown]
# ## Part 1: Getting your data
#
# Create a google form to input your data.
# Follow the same method as [Lab 5](https://colab.research.google.com/drive/1zYvyhrz2wVnJXlZqj_PpxOxplfS3LN9Y?usp=sharing).

# %%
import pandas as pd 
def get_database(url): # This function loads the google spreadsheet of data
    url_head = "https://docs.google.com/spreadsheets/d/" 
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5] #split at the '/' and take the 6th
    sheet_name = "1" #just naming the sheet
    url_csv = url_head + url_body + url_foot + sheet_name #combining all terms and creating a link to the csv file
    df = pd.read_csv(url_csv, sep=',', skiprows=0) #saying to read the file from the url, separate the data with a comma, and to skip row 0
    return df #returns an array like "dataframe (df)"

# %% [markdown]
# Put your form url here:

# %%
url = 'https://docs.google.com/spreadsheets/d/1fiS05wwWMA5zUhE-NxvDGg3AUBxeuINo9VZA0_5AFyU/edit?usp=sharing' #defining the variable of url as the link

# %%
print (url.split('/')) #url_body is the ID of the spreadsheet "'1fiS05wwWMA5zUhE-NxvDGg3AUBxeuINo9VZA0_5AFyU'"
# Out:
# ['https:', '', 'docs.google.com', 'spreadsheets', 'd', '1fiS05wwWMA5zUhE-NxvDGg3AUBxeuINo9VZA0_5AFyU', 'edit?usp=sharing']

# %%
data = get_database(url) #defining data as a variable that will get the information from the url

# %%
data.values
# Out:
# array([['10/20/2022 0:23:55', 'Circle1', 22, 7],
#        ['10/20/2022 0:24:06', 'Circle 2', 14, 4],
#        ['10/20/2022 0:24:15', 'Circle 3', 25, 8],
#        ['10/20/2022 0:24:26', 'Circle 4', 61, 20],
#        ['10/20/2022 0:24:37', 'Circle 5', 16, 5]], dtype=object)

# %%
circumferences = (22, 14, 25, 61, 16)
diameters = (7, 4, 8, 20, 5)

# %%
C = np.array([22, 14, 25, 61, 16]) #creating an array with the circumferemce numbers 
D = np.array([7, 4, 8, 20, 5])  #creating an array with the diameter numbers

# %% [markdown]
# Plot your data points

# %%
plt.plot(D,C,'.'); #creating a plot of C and D with "." as the marker

# %%
x = D #putting these numbers into variables that fit the y=mx+b format
y = C

# %%
plt.title("Circle Diameter vs Circumference") #labeling the entire graph

plt.xlabel('Diameter') #labeling the x axis
plt.ylabel('Circumference') #labeling the y axis

plt.plot(x,y, '.'); #telling the computer to plot the numbers stored in x and y, using the period/dot as the marker

# %% [markdown]
# ## Part 2: Linear Fit
#
# Follow the steps in the [Linear Fit notebook]() to run a linear fit on your data.

# %%
best_loss = 100000 #the least squared error
best_m = 0
best_b = 0 

for m_guess in np.linspace(-100,100,100): #going from -100 to 100 with 100 steps in between
    for b_guess in np.linspace(-100,100,100): #for loops say that for everything in that linspace, run the block below it, and the same for b_guess.  
    #running this 100 times for the outer block and for every 100 times in the outer block, you run it 100 time on the inner block   
        
        y_guess = m_guess * x + b_guess
        
        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess

# %%
y_guess = best_m * x + best_b

# %%
y_guess
# Out:
# array([22.22222222, 13.13131313, 25.25252525, 61.61616162, 16.16161616])

# %%
y_guess = best_m * x + best_b #just using the y=mx+b formula to get the best guess for y

plt.plot(x,y_guess,'r'); #plotting x and the y guess in red
plt.plot(D,C,'g.'); #plotting the circumference and diameter points in green
plt.show()

print(best_loss,best_m,best_b)
# Out:
# 1.2735435159677813 3.030303030303031 1.0101010101010104

# %% [markdown]
# Plot the line of best fit:
#
# Use blue dots for the collected data and a red line for the estimate.

# %% [markdown]
# Below is the same block of code as line 12 except you plot x and y separately in red and blue and print the best guesses with the lowest loss for the line of best fit

# %%
best_loss = 100000 
best_m = 0
best_b = 0 

for m_guess in np.linspace(-100,100,100): 
    for b_guess in np.linspace(-100,100,100):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess

            plt.plot(x,y_guess, 'r');
            plt.plot(x,y,'b.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 98654.96194265879 -17.171717171717162 100.0
# 98267.3280277521 -15.151515151515142 67.6767676767677
# 96403.7630853993 -15.151515151515142 69.69696969696972
# 94581.01030507074 -15.151515151515142 71.71717171717174
# 92799.06968676652 -15.151515151515142 73.73737373737376
# 91057.94123048651 -15.151515151515142 75.75757575757578
# 89357.62493623086 -15.151515151515142 77.7777777777778
# 87698.12080399944 -15.151515151515142 79.79797979797982
# 86079.42883379234 -15.151515151515142 81.81818181818184
# 84501.54902560948 -15.151515151515142 83.83838383838386
# 82964.48137945095 -15.151515151515142 85.85858585858588
# 81468.22589531666 -15.151515151515142 87.8787878787879
# 80012.78257320668 -15.151515151515142 89.89898989898992
# 78598.15141312096 -15.151515151515142 91.91919191919195
# 77224.33241505957 -15.151515151515142 93.93939393939394
# 75891.32557902244 -15.151515151515142 95.95959595959596
# 74599.13090500957 -15.151515151515142 97.97979797979798
# ...

# %% [markdown]
# 1 is a great error number so that is the line of best fit

# %%
x
# Out:
# array([ 7,  4,  8, 20,  5])

# %%
plt.title('Linear Fit of Circles')

plt.xlabel('Diameter in cm')
plt.ylabel('Circumference in cm')

# Plot the collected data
plt.plot(D, C, 'b.', label='Observations')

y_estimate = best_m * x + best_b 

# Plot the line of best fit
plt.plot(x, y_estimate, 'r', label=f'Estimate: $y = {best_m} x + {best_b}$')

plt.legend();

# %%
best_m
# Out:
# 3.030303030303031

# %% [markdown]
# The estimated relationship is:
#
# $C = ? D + ?$
#
# $C = 3.03D+1.01$

# %% [markdown]
# ## Part 3: Interpretation
#
# Answer the questions in text cells

# %% [markdown]
# #### Question 1:
#
# What do $m$ and $b$ represent in these equations?

# %% [markdown]
# $m$ is the slope of the line and $b$ is $y$ when $x$ = 0 (the intercept)

# %% [markdown]
# #### Question 2:
#
# Guess what the correct values $m$ and $b$ should be.

# %% [markdown]
# $m$ should be around 3 and $b$ should be around 1

# %% [markdown]
# #### Question 3:
#
# Does it make sense to include $b$ in the parameters?

# %% [markdown]
# yes, because it's the intercept so it's needed for the line of fit to exist

# %% [markdown]
# ## Bonus:
#
# These problems are extra credit. You may use any resources, but be sure to explain your code.

# %% [markdown]
# #### Bonus 1: Plot the squared errors from your line of best fit

# %%
plt.title("Fit Errors")

plt.xlabel("Diameter")
plt.ylabel("Squared Error")

squared_error = ...

plt.plot(..., 'b.', label = "Errors")

plt.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-77c7485c31ce> in <module>
#       6 squared_error = ...
#       7
# ----> 8 plt.plot(..., 'b.', label = "Errors")
#       9
#      10 plt.legend();
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# -> 1649             self.add_line(line)
#    1650         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1651         return lines
# ...

# %% [markdown]
# #### Bonus 2: Plot the errors as a histogram

# %%
plt.title("Errors")

...

# %% [markdown]
# What distribution does this histogram look like?

# %% [markdown]
# #### Bonus 3: Find the circle with the largest error.
# Hint: use np.max

# %%
largest_error = ...

# %% [markdown]
# #### Bonus 4: Remove the circles with the 2 largest errors and run the fit again.

# %%
...

# %% [markdown]
# What is the difference in your error?

# %% [markdown]
# #### Bonus 5: Find and explain a better method of fitting this data
