# %% [markdown]
# <a href="https://colab.research.google.com/github/maefl0wer/Statistics2022/blob/main/Bloom_Lab6LinearFit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
#normal imports for python
import pandas as pd
import urllib.request
#new imports for linear fit/regression lab

# %%
url = "https://raw.githubusercontent.com/maefl0wer/Statistics2022/main/cereal_data.csv"
#pasting in as a string from raw data in my github and defining the link as the variable "url"

# %%
urllib.request.urlretrieve(url, 'cereal_data.csv') #using the urllib command to import the data from github into python
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7fb887630110>)

# %%
cereal_data = pd.read_csv('cereal_data.csv') #defining "cereal_data" and using panda (pd.read) to get the data

# %%
cereal_data #shows the raw data in a new table
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data

# %%
cereal_data["sugars"] #gives us the data for the amount of sugar in each cereal. Cereal number is on the left, sugar amount is on the right
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data["potass"] #same as above but with potassium levels
# Out:
# 0     280
# 1     135
# 2     320
# 3     330
# 4      -1
#      ...
# 72     60
# 73     25
# 74    115
# 75    110
# 76     60
# Name: potass, Length: 77, dtype: int64

# %%
cereal_data[["calories","sugars"]] #gives data for both calories and sugars. note the use of double square brackets for two variables
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
cereal_data["sugars"].mean() #will give the mean/average of all the cereal's sugar
# Out:
# 6.922077922077922

# %%
cereal_data[["calories","sugars"]].mean() #mean of both calories and sugars
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
plt.plot(cereal_data[["sugars"]], cereal_data[["calories"]],'.'); #plotting the cereal data of sugars and calories against each other

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.'); #make sure to define a point marker or else it will connect all of the dots and not make sense

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("sugars")
plt.ylabel("calories")
plt.title("calories vs sugars"); 
#same plot as before but adding labels and a title

# %%
x = cereal_data[["fat"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("fat")
plt.ylabel("calories")
plt.title("calories vs fat"); #just changes sugars to fat

# %%
x = cereal_data[["fiber"]]
y = cereal_data[["vitamins"]]

plt.plot(x,y,'.')
plt.xlabel("fiber")
plt.ylabel("vitamins")
plt.title("fiber vs vitamins");

# %%
X = cereal_data[["carbo"]]
Y = cereal_data[["rating"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X,Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y, '.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
x = np.linspace(0,10,50) #0-10 in 50 parts

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
m = 3
b = 7

y = m * x + b

# %%
plt.plot(x,y,'.');

# %%
noise = 10 * np.random.rand(50,) #50 points of random noise numbers

# %%
y = m * x + b + noise

# %%
plt.plot(x,y, '.'); #synthetic data set

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess, 'r.'); #r. is red dots
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess, 'r.'); 
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 13

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess, 'r.'); 
plt.plot(x,y,'g.'); #just going through and changing the numbers to see if i can find the line of best fit manually

# %%
loss = np.sum((y_guess - y)**2) #defining loss as the sum of the y_guess minus y squared

# %%
loss #the loss number we are given is arounf 41
# Out:
# 471.0965200721153

# %%
for m_guess in np.linspace(-10,10,10):
  print(m_guess) #printing the m guesses
# Out:
# -10.0
# -7.777777777777778
# -5.555555555555555
# -3.333333333333333
# -1.1111111111111107
# 1.1111111111111107
# 3.333333333333334
# 5.555555555555557
# 7.777777777777779
# 10.0

# %%
for m_guess in np.linspace(-10,10,10):
  for b_guess in np.linspace(-10,10,10):

    y_guess = m_guess * x + b_guess

    plt.plot(x,y_guess,'r.');
    plt.plot(x,y,'g.');
    plt.show()

    loss + np.sum((y_guess - y)**2)

    print(loss,m_guess,b_guess) #printing a loop of guesses to find where the best fit is using the y and m guesses
# Out:
# 471.0965200721153 -10.0 -10.0
# 471.0965200721153 -10.0 -7.777777777777778
# 471.0965200721153 -10.0 -5.555555555555555
# 471.0965200721153 -10.0 -3.333333333333333
# 471.0965200721153 -10.0 -1.1111111111111107
# 471.0965200721153 -10.0 1.1111111111111107
# 471.0965200721153 -10.0 3.333333333333334
# 471.0965200721153 -10.0 5.555555555555557
# 471.0965200721153 -10.0 7.777777777777779
# 471.0965200721153 -10.0 10.0
# 471.0965200721153 -7.777777777777778 -10.0
# 471.0965200721153 -7.777777777777778 -7.777777777777778
# 471.0965200721153 -7.777777777777778 -5.555555555555555
# 471.0965200721153 -7.777777777777778 -3.333333333333333
# 471.0965200721153 -7.777777777777778 -1.1111111111111107
# 471.0965200721153 -7.777777777777778 1.1111111111111107
# 471.0965200721153 -7.777777777777778 3.333333333333334
# 471.0965200721153 -7.777777777777778 5.555555555555557
# 471.0965200721153 -7.777777777777778 7.777777777777779
# 471.0965200721153 -7.777777777777778 10.0
# ...

# %%
3.333333333333334 10.0

# %%
best_loss = 100000
best_m = 0
best_b = 0
for m_guess in np.linspace(-10,10,20):
  for b_guess in np.linspace(-10,10,20):

    y_guess = m_guess * x + b_guess

    loss = np.sum((y_guess - y)**2)

    if loss < best_loss:

      best_loss = loss
      best_m = m_guess
      best_b = b_guess

      plt.plot(x,y_guess, 'r.');
      plt.plot(x,y,'g.');
      plt.show()

      print(loss,m_guess,b_guess)

#same thing as before but structured to make it easier to get data from and will automatically stop at the line of the best fit
# Out:
# 98575.98412276387 -3.6842105263157894 5.789473684210526
# 94440.22746040946 -3.6842105263157894 6.842105263157894
# 90415.27412215475 -3.6842105263157894 7.894736842105264
# 86501.12410799979 -3.6842105263157894 8.94736842105263
# 82697.77741794456 -3.6842105263157894 10.0
# 80958.28012133193 -2.6315789473684212 3.6842105263157894
# 77154.93343127669 -2.6315789473684212 4.7368421052631575
# 73462.39006532116 -2.6315789473684212 5.789473684210526
# 69880.65002346535 -2.6315789473684212 6.842105263157894
# 66409.71330570927 -2.6315789473684212 7.894736842105264
# 63049.57991205293 -2.6315789473684212 8.94736842105263
# 59800.2498424963 -2.6315789473684212 10.0
# 58467.78516502551 -1.578947368421053 3.6842105263157894
# 55218.45509546888 -1.578947368421053 4.7368421052631575
# 52079.92835001198 -1.578947368421053 5.789473684210526
# 49052.20492865478 -1.578947368421053 6.842105263157894
# 46135.28483139732 -1.578947368421053 7.894736842105264
# ...
